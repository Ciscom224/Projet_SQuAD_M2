# %% [markdown]
# # Projet SQUAD

# %% [markdown]
# ## Exploiration des donnees

# %%
# code

# %% [markdown]
# ## Pre-traitement des donnees

# %% [markdown]
# ## Modele1 : nom_modele

# %% [markdown]
# ## Modele2 : nom_modele
